# %% [markdown]
# # Questions

# %% [markdown]
# **Question 1: Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.**
#   - NLTK:-
#     - It is a Python library mainly designed for teaching and research in Natural Language Processing.
#     - It provides a wide range of NLP tools such as Tokenization, Stemming and Lemmatization, Part-of-Speech tagging, Parsing, Text classification.
#     - Its beginner-friendly and widely used in academics and requires more coding for basic tasks and also good for understanding core NLP concepts step-by-step.
#   - SpaCy:-
#     - It is a modern NLP library designed for industrial and production-level applications.
#     - It provides an advanced NLP pipeline including Tokenization, POS tagging,Named Entity Recognition, Dependency parsing, Lemmatization.
#     - Its a simple and clean API which performs multiple NLP tasks using a single pipeline command and easier to implement in real-world projects.

# %% [markdown]
# **Question 2: What is TextBlob and how does it simplify common NLP tasks like
# sentiment analysis and translation?**
#   - TextBlob is a Python library for processing textual data.
#   - It is built on top of NLTK and Pattern.
#   - It provides a simple and user-friendly API for performing common NLP tasks.
#   - And designed for beginners and rapid development.
#   - It performs sentiment analysis with just a few lines of code and returns Polarity range from -1 to +1 or Subjectivity range from 0 to 1.
#   - It provides a simple method to translate text between languages.
#   - It automatically detects the source language.
#   - It uses external translation services.
#   - Requires minimal code to perform translation.

# %% [markdown]
# **Question 3: Explain the role of Standford NLP in academic and industry NLP Projects.**
#   - Stanford NLP refers to a group of Natural Language Processing tools developed by Stanford University.
#   - It includes widely used tools like Stanford CoreNLP and modern libraries such as Stanza.
#   - These tools are used in both academic research and industry applications.
#   - **Role of Stanford NLP in Academic Projects**
#     - Research and Development
#       - Provides state-of-the-art NLP models for experimentation.
#       - Used in linguistic research and computational linguistics studies.
#       - Helps researchers develop and test new NLP algorithms.
#     - Teaching and Learning
#       - Commonly used in universities for NLP coursework.
#       - Offers well-documented tools for understanding parsing, tagging, and semantic analysis.
#       - Supports multiple languages, making it useful for multilingual research.
#     - Access to Annotated Corpora
#       - Provides pre-trained models and annotated datasets.
#       - Helps students and researchers work on real-world NLP tasks.
#   - **Role of Stanford NLP in Industry Projects**
#     - Information Extraction
#       - Used for Named Entity Recognition (NER), POS tagging, and relation extraction.
#       - Helps extract useful information from large volumes of text data.
#     - Sentiment Analysis
#       - Applied in analyzing customer feedback, reviews, and social media posts.
#     - Chatbots and Virtual Assistants
#       - Supports dependency parsing and entity recognition for conversational AI systems.

# %% [markdown]
# **Question 4: Describe the architecture and functioning of a Recurrent Natural Network (RNN).**
#   - A Recurrent Neural Network (RNN) is a type of artificial neural network designed to handle sequential data.
#   - It is mainly used in tasks like language modeling, speech recognition, and time-series prediction.
#   - Unlike feedforward neural networks, RNNs have memory to store information about previous inputs.
#   - It consists of Input layer, Hidden layer, Output layer.
#   - The hidden layer has a loop, this loop allows information to persist across time steps.
#   - RNN can be visualized as being unfolded across time steps.
#   - Each time step shares the same weights.
#   - This weight sharing reduces the number of parameters.

# %% [markdown]
# **Question 5: What is the key difference between LSTM and GRU networks in NLP applications?**
#   - LTMS:-
#     - It contains three gates Input Gate, Forget Gate and Output Gate.
#     - It has a separate cell state to store long-term memory.
#     - More complex architecture.
#     - LSTM maintains a separate cell state to store long-term information.
#     - LSTM has more parameters due to additional gates.
#   - GRU:-
#     - It contains two gates Update Gate and Reset Gate.
#     - It combines hidden state and cell state into a single state.
#     - Simpler architecture compared to LSTM.
#     - GRU does not have a separate cell state; it merges the cell state and hidden state.
#     - GRU has fewer parameters and is computationally lighter.

# %%
# Question 6: Write a Python program using TextBlob to perform sentiment analysis on the following paragraph of text:
'''I had a great experience using the new mobile banking app. The interface is intuitive,
and customer support was quick to resolve my issue. However, the app did crash once
during a transaction, which was frustrating'''
# Your program should print out the polarity and subjectivity scores


from textblob import TextBlob

text = """
I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating.
"""
blob = TextBlob(text)
polarity = blob.sentiment.polarity
subjectivity = blob.sentiment.subjectivity

print("Polarity Score:", polarity)
print("Subjectivity Score:", subjectivity)
# Out:
# Polarity Score: 0.21742424242424244
# Subjectivity Score: 0.6511363636363636

# %%
# Question 7: Given the sample paragraph below, perform string tokenization and frequency distribution using Python and NLTK:
'''Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical.'''

import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')
nltk.download('punkt_tab')
text = """
Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical.
"""

text = text.lower()
tokens = word_tokenize(text)
words = [word for word in tokens if word.isalpha()]
freq_dist = FreqDist(words)

print("Tokens:")
print(words)
print("\nFrequency Distribution:")
for word, frequency in freq_dist.items():
    print(f"{word}: {frequency}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens:
# ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', 'computer', 'science', 'and', 'artificial', 'intelligence', 'it', 'enables', 'machines', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'applications', 'of', 'nlp', 'include', 'chatbots', 'sentiment', 'analysis', 'and', 'machine', 'translation', 'as', 'technology', 'advances', 'the', 'role', 'of', 'nlp', 'in', 'modern', 'solutions', 'is', 'becoming', 'increasingly', 'critical']
#
# Frequency Distribution:
# natural: 1
# language: 2
# processing: 1
# nlp: 3
# is: 2
# a: 1
# fascinating: 1
# field: 1
# that: 1
# combines: 1
# linguistics: 1
# computer: 1
# science: 1
# and: 3
# artificial: 1
# ...

# %%
# Question 8: Implement a basic LSTM model in Keras for a text classification task using the following dummy dataset. Your model should classify sentences as either positive (1) or negative (0).
# Dataset
'''texts = [
“I love this project”, #Positive
“This is an amazing experience”, #Positive
“I hate waiting in line”, #Negative
“This is the worst service”, #Negative
“Absolutely fantastic!” #Positive
]
labels = [1, 1, 0, 0, 1]'''
# Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on this data. You may use Keras with TensorFlow backend.

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]

labels = [1, 1, 0, 0, 1]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
max_length = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_length, padding='post')

y = np.array(labels)
vocab_size = len(tokenizer.word_index) + 1

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=16, input_length=max_length),
    LSTM(32),
    Dense(1, activation='sigmoid')
])
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
model.summary()

model.fit(X, y, epochs=20, verbose=1)
test_text = ["I really love this service"]
test_seq = tokenizer.texts_to_sequences(test_text)
test_pad = pad_sequences(test_seq, maxlen=max_length, padding='post')

prediction = model.predict(test_pad)
print("Prediction:", prediction)
print("Class:", 1 if prediction[0][0] > 0.5 else 0)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ...

# %%
# Question 9: Using spaCy, build a simple NLP pipeline that includes tokenization, lemmatization, and entity recognition. Use the following paragraph as your dataset:
'''“Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India.”'''
# Write a Python program that processes this text using spaCy, then prints tokens, their lemmas, and any named entities found.

import spacy
nlp = spacy.load("en_core_web_sm")
text = """
Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India.
"""
doc = nlp(text)
print("TOKENS AND LEMMAS:\n")
for token in doc:
    print(f"Token: {token.text} \t Lemma: {token.lemma_}")
print("\nNAMED ENTITIES:\n")
for ent in doc.ents:
    print(f"Entity: {ent.text} \t Label: {ent.label_}")
# Out:
# TOKENS AND LEMMAS:
#
# Token:
#  	 Lemma:
#
# Token: Homi 	 Lemma: Homi
# Token: Jehangir 	 Lemma: Jehangir
# Token: Bhaba 	 Lemma: Bhaba
# Token: was 	 Lemma: be
# Token: an 	 Lemma: an
# Token: Indian 	 Lemma: indian
# Token: nuclear 	 Lemma: nuclear
# Token: physicist 	 Lemma: physicist
# Token: who 	 Lemma: who
# Token: played 	 Lemma: play
# Token: a 	 Lemma: a
# Token: key 	 Lemma: key
# Token: role 	 Lemma: role
# Token: in 	 Lemma: in
# Token: the 	 Lemma: the
# Token:
#  	 Lemma:
#
# Token: development 	 Lemma: development
# Token: of 	 Lemma: of
# Token: India 	 Lemma: India
# Token: ’s 	 Lemma: ’s
# Token: atomic 	 Lemma: atomic
# Token: energy 	 Lemma: energy
# Token: program 	 Lemma: program
# Token: . 	 Lemma: .
# Token: He 	 Lemma: he
# Token: was 	 Lemma: be
# Token: the 	 Lemma: the
# Token: founding 	 Lemma: found
# Token: director 	 Lemma: director
# Token: of 	 Lemma: of
# Token: the 	 Lemma: the
# Token: Tata 	 Lemma: Tata
# Token:
#  	 Lemma:
#
# ...
